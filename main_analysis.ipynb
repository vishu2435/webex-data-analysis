# %%
import pandas as pd

# %%
df = pd.read_csv('./GSB SEC Meet #1 Logs.txt',sep='\n',header=None)
df
# Out:
#                                                       0
# 0     from Hariharan Balasubramanian to everyone:   ...
# 1     @IITM Host - Please make me, Kunwar, Abhinandh...
# 2     from Hariharan Balasubramanian to everyone:   ...
# 3                                           Abishek too
# 4     from Hariharan Balasubramanian to everyone:   ...
# ...                                                 ...
# 5444                                     thank you team
# 5445                   from Alf to everyone:    8:31 PM
# 5446  ananya 21f3001596@student.online degree.iitm.a...
# 5447      from Abhinandan Sethi to everyone:    8:31 PM
# 5448                https://forms.gle/hFCySMUHsDjDE73x7
#
# [5449 rows x 1 columns]

# %%
# selected = []
# for i in df[0]:
#     try:
#         if i :
#             print(i)
#             selected.append(i)
#     except:
#         print()

# %%
# selected

# %%
# house_rollno = []
# for i in selected:
# #     print(i)
#     if i.startswith('21f') or i.startswith('22f'):
#         house_rollno.append(i)

# %%
# house_rollno

# %%
# for i in house_rollno:
#     if 'student.onlinedegree.iitm.ac.in' in i:
#         house_rollno.remove(i)

# %%
# house_rollno

# %%
# selected

# %%
import re
email_regex = "[0-9]+[\w+\d+]*@[\w\.\w]*"
students_intrested=[]
for i in df[0]:
#     print(i)
    i = str(i)
#     print(i)
#     print(re.findall(r"[0-9]+[\w+\d+]*@[\w\.\w]*",i,re.IGNORECASE))
    if i and len(re.findall(email_regex,i,re.IGNORECASE))>0:
        students_intrested.append(i)

# %%
re.
# Out:
#   File "<ipython-input-23-7e1da8ee0506>", line 1
#     re.
#        ^
# SyntaxError: invalid syntax

# %%
students_intrested
# Out:
# ['21f3002289@student.onlinedegree.iitm.ac.in',
#  '21f3002289@student.onlinedegree.iitm.ac.in',
#  'Somya Shukla      21f3001382@student.onlinedegree.iitm.ac.in',
#  '21f3001382@student.onlinedegree.iitm.ac.in  can you please give me my details',
#  '21f1004192@student.onlinedegree.iitm.ac.in',
#  '21f3003255@student.onlinedegree.iitm.ac.in',
#  '21f3002966@student.onlinedegree.iitm.ac.in',
#  '21f1001180@student.onlinedegree.iitm.ac.in',
#  '21f3002506@student.onlinedegree.iitm.ac.in',
#  'mitr 21f3003219@student.onlinedegree.iitm.ac.in',
#  'mitra 21f1000080@student.onlinedegree.iitm.ac.in',
#  'Mitr - 21f3002203@student.onlinedegree.iitm.ac.in',
#  'khushalagrawal2821@gmail.com',
#  'mitr - 21f1005470@student.onlinedegree.iitm.ac.in',
#  'mitr 21f3001270@student.onlinedegree.iitm.ac.in',
#  'MiTr : 21f1005207@student.onlinedegree.iitm.ac.in',
#  'mitr-21f1004146@student.onlinedegree.iitm.ac.in',
#  'mitr 21f1003354@student.onlinedegree.iitm.ac.in',
# ...

# %%
mitr = []
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*mi[tra]\w+',i,re.IGNORECASE):
        print(i)
        mitr.append(i)
# Out:
# mitr 21f3003219@student.onlinedegree.iitm.ac.in
# mitra 21f1000080@student.onlinedegree.iitm.ac.in
# Mitr - 21f3002203@student.onlinedegree.iitm.ac.in
# mitr - 21f1005470@student.onlinedegree.iitm.ac.in
# mitr 21f3001270@student.onlinedegree.iitm.ac.in
# MiTr : 21f1005207@student.onlinedegree.iitm.ac.in
# mitr-21f1004146@student.onlinedegree.iitm.ac.in
# mitr 21f1003354@student.onlinedegree.iitm.ac.in
# mitr 21f2001351@student.onlinedegree.iitm.ac.in
# mitr- 21f1004271@student.onlinedegree.iitm.ac.in
# mitr 21f3001418@student.onlinedegree.iitm.ac.in
# Mitr 21f3003037@student.onlinedegree.iitm.ac.in
# Mitr: 21f1002593@student.onlinedegree.iitm.ac.in
# MITR  - aabdullahzeeshan77@gmail.com
# Mitr-21f3003219@student.onlinedegree.iitm.ac.in
# mitra Akshaya R akshayar800@gmal.com 21f1003313@student.onlinedegree.iitm.c.in
# Mitr 21f3001621@student.onlinedegree.iitm.ac.in
# Mitr - 21f3002626@student.onlinedegree.iitm.ac.in
# mitr 21f3002841@student.onlinedegree.iitm.ac.in
# ...

# %%
research = []
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*res[ea]\w+',i,re.IGNORECASE):
        print(i)
        research.append(i)
research
# Out:
# RESEARCH:21f3002196@student.onlinedegree.iitm.ac.in
# research - 21f1006682@student.onlinedegree.iitm.ac.in
# research- 21f3000805@student.onlinedegree.iitm.ac.in
# research - 21f1004498@student.onlinedegree.iitm.ac.in
# research- 21f3001919@student.onlinedegree.iitm.ac.in
# Research - 21f3002962@student.onlinedegree.iitm.ac.in
# Research - 21f1004271@student.onlinedegree.iitm.ac.in
# Research Wing: 21f2000223@student.onlinedegree.iitm.ac.in
# Research 21f3003037@student.onlinedegree.iitm.ac.in
# research-21f1000907@student.onlinedegree.iitm.ac.in
# research 21f1001180@student.onlinedegree.iitm.ac.in
# research - 21f1000079@student.onlinedegree.iitm.ac.in
# Research - 21f1002870@student.onlinedegree.iitm.ac.in (Already have couple of publications in arXiv)
# Research 21f3002626@student.onlinedegree.iitm.ac.in
# research: 21f3003246@student.onlinedegree.iitm.ac.in
# research and entrepreneurship club 21f3002443@student.onlinedegree.iitm.ac.in
# ...

# %%
saathi = []
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*sa[ta]\w+',i,re.IGNORECASE):
        print(i)
        saathi.append(i)
len(saathi)
# Out:
# mitr and saathi - 21f3002375@student.onlinedegree.iitm.ac.in
# mitr and saathi 21f3002056@@student.onlinedegree.iitm.ac.in
# mitr, saathi 21f1005083@student.onlinedegree.iitm.ac.in
# sathi - 21f2001107@student.onlinedegree.iitm.ac.in
# MITR  &  Saathi Both 21f2000475@student.onlinedegree.iitm.ac.in
# Sathi 213002418@student.onlinedegree.iitm.ac.in
# saathi 21f1001738@student.onlinedegree.iitm.ac.in
# saathi 21f1006320@student.onlinedegree.iitm.ac.in
# saathi- 21f3002424@student.onlinedegree.iitm.ac.in
# saathi-22f1000296@student.onlinedegree.iitm.ac.in
# saathi-21f3002375@student.onlinedegree.iitm.ac.in
# Saathi-21F3000432@student.onlinedegree.iitm.ac.in
# saathi21f3002502@student.onlinedegree.iitm.ac.in
# saathi-22f1000027@student.onlinedegree.iit.ac.in
# Saathi   21f3002196@student.onlinedegree.iitm.ac.in
# saathi 21f3001428@student.onlinedegree.iitm.ac.in
# sathi 21f2001532@student.onlinedegree.iitm.ac.in
# Saathi: 21f1002593@student.onlinedegree.iitm.ac.in
# ...

# %%
editorial = []
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*edi\w+',i,re.IGNORECASE):
        print(i)
        editorial.append(i)
# Out:
# editorial - 21f3002626@student.onlinedegree.iitm.ac.in
# Editorial - 21f3000887@student.onlinedegree.iitm.ac.in
# Editorial 21f3002196@student.onlinedegree.iitm.ac.in
# Editorials:21f3001923@student.onlinedegree.iitm.ac.in
# Editorial - 21f3003243@student.onlinedegree.iitm.ac.in
# editorial 21f3001418@student.onlinedegree.iitm.ac.in
# Saath mitr both Editorial also 21f3002579@student.onlinedegree.iitm.ac.in
# editorial - 21f3002898@student.onlinedegree.iitm.ac.in
# editorial : 21f1004870@student.onlinedegree.iitm.ac.in
# editorial 21f3001382@student.onlinedegree.iitm.ac.in
# editorial 21f1004221@student.onlinedegree.iitm.ac.in
# Editorial: 21f1006362@student.onlinedegree.iitm.ac.in
# editorial : 21f3002056@student.onlinedegree.iitm.ac.in
# editorial - 21f2001158@student.onlinedegree.iitm.ac.in
# Editorial: 21f3002826@student.onlinedegree.iitm.ac.in
# editorial 21f1005083@student.onlinedegree.iitm.ac.in
# Editorial : 21f3003204@student.onlinedegree.iitm.ac.in
# ...

# %%
developer = []
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*dev\w+',i,re.IGNORECASE):
        print(i)
        developer.append(i)
# Out:
# developer club 21f3001628@student.onlinedegree.iitm.ac.in
# developer club- 21f3001525@student.onlinedegree.iitm.ac.in
# house diagnostics developers club - 22f1000296@student.onlinedegree.iitm.ac.in
# developer clubs 21f3000285@student.onlinedegree.iitm.ac.in
# developer club- 21f3001270@student.onlinedegree.iitm.ac.in
# developer club - 21f3002552@student.onlinedegree.iitm.ac.in
# developers club 21f3003043@student.onlinedegree.iitm.ac.in
# developer club 21f3002289@student.onlinedegree.iitm.ac.in
# developer club - 21f3002424@student.onlinedegree.iitm.ac.in
# developer club:21f3001923@student.onlinedegree.iitm.ac.in
# Developer club: 21f1006362@student.onlinedegree.iitm.ac.in
# developer club - 21f3002626@student.onlinedegree.iitm.ac.in
# developer club 21f1001295@student.onlinedegree.iitm.ac.in
# Developer Club - 21f1002870@student.onlinedegree.iitm.ac.in
# developer club 21f3001621@student.onlinedegree.iitm.ac.in
# developer club - 21f1005470@student.onlinedegree.iitm.ac.in
# ...

# %%
print(re.match('\w*[" "a-z\D]*bl\w+','blog+mitr+developer',re.IGNORECASE))
# Out:
# <re.Match object; span=(0, 4), match='blog'>

# %%
blog = []
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*bl[og]\w+',i,re.IGNORECASE):
        print(i)
        blog.append(i)
len(blog)
# Out:
# Blog Edititorial team Akshaya R    21f1003313@student.onlinedegree.iitm.ac.in akshayar800@gmail.com
# blog-sankalp Arora, 21f1004054@student.onlinedegree.iitm.ac.in
# blog: Dev Khatri 21f3001150@student.onlinedegree.iitm.ac.in
# Blog + editorial :21f3001784@student.onlinedegree.iitm.ac.in
# Blog 21f3002833@student.onlinedegree.iitm.ac.in
# MITR, SAATHI, BLOG, DEVELOPER clubs: 21f3002126@onlinedegree.iitm.ac.in
# blog+mitr+developer club - 21f1003052@student.onlinedegree.iitm.ac.in
# Blog  cosmonotes101.blogspot.com  21f1005643@student.onlinedegree.iitm.ac.in
# blog & editorial  & saathi- 22f1000266@student.onlinedegree.iitm.ac.in
# blogs 213002418@student.onlinedegree.iitm.ac.in
# 10

# %%
placement_wing = []
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*pla\w+',i,re.IGNORECASE):
        print(i)
        placement_wing.append(i)
# Out:
# placement wing - 21f1002870@student.onlinedegree.iitm.ac.in
# placement wing-21f3002388@student.onlinedegree.iitm.ac.in
# placement wing - 21f3002203@student.onlinedegree.iitm.ac.in
# placement wing - 21f3002375@student.onlinedegree.iitm.ac.in
# placement wing - 21f3002094@student.onlinedegree.iitm.ac.in
# placement wing - 21f3003105@student.onlinedegree.iitm.ac.in
# placement wing 21f3003037@student.onlinedegree.iitm.ac.i
# placement wing 21f3001919@student.onlinedegree.iitm.ac.in
# placement wing - 21f1003057@student.onlinedegree.iitm.ac.in
# placement wing 21f3002602@student.onlinedegree.iitm.ac.in
# placement wing- 21f1001893@student.onlinedegree.iitm.ac.in
# placement wing 21f2001292@student.onlinedegree.iitm.ac.in
# placement wing 21f2001406@student.onlinedegree.iitm.ac.in
# Placement Wing:-21f1002706@student.onlinedegree.iitm.ac.in
# placement wing - 21f3002052@student.onlinedegree.iitm.ac.in
# placement wing 21f1004271@student.onlinedegree.iitm.ac.in
# ...

# %%
vue = []

for i in students_intrested:
    if re.match('\w*[" "a-z\D]*vu\w+',i,re.IGNORECASE):
        print(i)
        vue.append(i)
# Out:
# vue 21f3002375@student.onlinedegree.iitm.ac.in
# vue - 21f3000887@student.onlinedegree.iitm.ac.in
# vue-21f3003192@student.onlinedegree.iitm.ac.in
# vue- 21f3002692@student.onlinedegree.iitm.ac.in
# vue - 21f1003313@student.onlinedegree.iitm.ac.in
# vue - 21f3001270@student.onlinedegree.iitm.ac.in
# vue - 21f3003243@student.onlinedegree.iitm.ac.in
# vue-21f3002388@student.onlinedegree.iitm.ac.in
# vue - 21f1002513@student.onlinedegree.iitm.ac.in
# Vue 21f3002602@student.onlinedegree.iitm.ac.in
# vue - 21f3001677@student.onlinedegree.iitm.ac.in
# Vue - 21f1004921@student.onlinedegree.iitm.ac.in
# vue - 21f3001919@student.onlinedegree.iitm.ac.in
# vue- 21f3003053@student.onlinedegree.iitm.ac.in
# vue 21f3002841@student.onlinedegree.iitm.ac.in
# vue - 21f3002056@student.onlinedegree.iitm.ac.in
# Vue - 21f3000285@student.onlinedegree.iitm.ac.in
# vue-21f3002388@student.onlinedegree.iitm.ac.in
# vue - 21f2000045@student.onlinedegree.iitm.ac.in
# ...

# %%
regional_coordinator = []

for i in students_intrested:
    if re.match('\w*[" "a-z\D]*reg\w+',i,re.IGNORECASE):
        print(i)
        regional_coordinator.append(i)
# Out:
# Regional coordinator21f1003017@student.onlinedegree.iitm.ac.in
# regional coordinator 21f3000285@student.onlinedegree.iitm.ac.in
# regional :- developers club -21f1000053@student.onlinedegree.iitm.ac.in
# regional coordinators:21f3001923@student.onlinedegree.iitm.ac.in
# Regional Coordinator - 21f1005470@student.onlinedegree.iitm.ac.in
# regional coodinator: 21f3001150@student.onlinedegree.iitm.ac.in
# regional coordinator : 21f3002203@student.onlinedegree.iitm.ac.in
# Regional co-ordinator Bangalore Akshaya R 21f1003313@student.onlinedegree.iitm.ac.in
# regional cooridnators 21f3003043@student.onlinedegree.iitm.ac.in
# Regional coordinator Mumbai 21f1000859@student.onlinedegree.iitm.ac.in
# regional coordinator 21f3001496@student.onlinedegree.iitm.ac.in
# regional:--21f1000053@student.onlinedegree.iitm.ac.in
# regional coordinators-21f1000886@student.onlinedegree.iitm.ac.in
# Regional Coordinator - 21f3002764@student.onlinedegree.iitm.ac.in
# ...

# %%
physical_meetup = []

for i in students_intrested:
    if re.match('\w*[" "a-z\D]*phy\w+',i,re.IGNORECASE):
        print(i)
        physical_meetup.append(i)
# Out:
# physical meet up 21f3001596@student.online degree.iitm.ac.in
# physical meet-up would be great21f3000448@student.onlinedegree.iitm.ac.in
# physical meet-21f1000886@student.onlinedegree.iitm.ac.in
# physical meet 21f3002295@student.onlinedegree.iitm.ac.in
# Physical Meetups:21f2001186@student.onlinedegree.iitm.ac.in
# Physical meetups-21f1000886@student.onlinedegree.iitm.ac.in
# Physical ad Regional 21f2000844@student.onlinedegree.iitm.ac.in
# physical meetups 21f3002289@student.onlinedegree.iitm.ac.in
# physical meet 21f3002502@student.onlinedegree.iitm.ac.in
# physical meet -21f2001158@student.onlinedegree.iitm.ac.in
# Regional Coordinator & Physical Meet-ups (Agra)- Adamya Vatsalya Sharma 21F3000432@student.onlinedegree.iitm.ac.in

# %%
entrepreneurship = []
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*ent\w+',i,re.IGNORECASE):
        print(i)
        entrepreneurship.append(i)
entrepreneurship.pop(0)
entrepreneurship.pop(0)
len(entrepreneurship)
entrepreneurship
# Out:
# I had managed my school events 21f3002418@student.onlinedegree.iitm.ac.in
# placements: 21f3002815@student.onlinedegree.iitm.ac.in
# enturprunership-21f3002388@student.onlinedegree.iitm.ac.in
# enturprenurship-21f3002388@student.onlinedegree.iitm.ac.in
# entrepreneur - 21f3001048@student.onlinedegree.iitm.ac.in
# enterpreneurship- 21f2000711@student.onlinedegree.iitm.ac.in
# entrepreneurship- 21f3003105@student.onlinedegree.iitm.ac.in
# Entrepeneurship - 21f3003243@student.onlinedegree.iitm.ac.in
# i want to join enterpreneuship club and developer club - 22f1000188@student.onlinedegree.iitm.ac.in
# entrepreneurship group- sankalp Arora 21f1004054@student.onlinedegree.iitm.ac.in
# entrepreneurship 21f3003037@student.onlinedegree.iitm.ac.in
# entrepreneur ​​21f3000805@student.onlinedegree.iitm.ac.in
# entrepreneurship ,21f2001058@student.onlinedegree.iitm.ac.in
# entrepreneurship- 21f3002962@student.onlinedegree.iitm.ac.in
# entrepreneurship 21f2001351@student.onlinedegree.iitm.ac.in
# ...

# %%
groups = {
    'mitr':mitr,
    'editorial':editorial,
    'developer':developer,
    'blog':blog,
    'placement wing':placement_wing,
    'vue':vue,
    'regional coordinator':regional_coordinator,
    'physical meetup':physical_meetup,
    'research':research,
    'saathi':saathi,
    'enterpreneurship':entrepreneurship
}
students_dict = {}
email_regex = "[0-9]+[\w+\d+]*@[\w\.\w]*"
for grp in groups.keys():
    for i in groups[grp]:
        x = re.findall(email_regex,i)
        print(x)
        if len(x)>0: 
            if x[0] in students_dict:
                students_dict[x[0]].add(grp)
            else:
                students_dict[x[0]] = {grp}
# Out:
# ['21f3003219@student.onlinedegree.iitm.ac.in']
# ['21f1000080@student.onlinedegree.iitm.ac.in']
# ['21f3002203@student.onlinedegree.iitm.ac.in']
# ['21f1005470@student.onlinedegree.iitm.ac.in']
# ['21f3001270@student.onlinedegree.iitm.ac.in']
# ['21f1005207@student.onlinedegree.iitm.ac.in']
# ['21f1004146@student.onlinedegree.iitm.ac.in']
# ['21f1003354@student.onlinedegree.iitm.ac.in']
# ['21f2001351@student.onlinedegree.iitm.ac.in']
# ['21f1004271@student.onlinedegree.iitm.ac.in']
# ['21f3001418@student.onlinedegree.iitm.ac.in']
# ['21f3003037@student.onlinedegree.iitm.ac.in']
# ['21f1002593@student.onlinedegree.iitm.ac.in']
# ['77@gmail.com']
# ['21f3003219@student.onlinedegree.iitm.ac.in']
# ['800@gmal.com', '21f1003313@student.onlinedegree.iitm.c.in']
# ['21f3001621@student.onlinedegree.iitm.ac.in']
# ['21f3002626@student.onlinedegree.iitm.ac.in']
# ['21f3002841@student.onlinedegree.iitm.ac.in']
# ['21f3001496@student.onlinedegree.iitm.ac.in']
# ...

# %%
len(students_dict.keys())
# Out:
# 250

# %%
for i in students_dict.keys():
    students_dict[i] = sorted(students_dict[i])
    

students_dict
# Out:
# {'21f3003219@student.onlinedegree.iitm.ac.in': ['developer',
#   'mitr',
#   'placement wing',
#   'regional coordinator',
#   'vue'],
#  '21f1000080@student.onlinedegree.iitm.ac.in': ['developer', 'mitr'],
#  '21f3002203@student.onlinedegree.iitm.ac.in': ['mitr',
#   'placement wing',
#   'regional coordinator'],
#  '21f1005470@student.onlinedegree.iitm.ac.in': ['developer',
#   'mitr',
#   'regional coordinator'],
#  '21f3001270@student.onlinedegree.iitm.ac.in': ['developer', 'mitr', 'vue'],
#  '21f1005207@student.onlinedegree.iitm.ac.in': ['mitr'],
#  '21f1004146@student.onlinedegree.iitm.ac.in': ['mitr'],
#  '21f1003354@student.onlinedegree.iitm.ac.in': ['mitr'],
#  '21f2001351@student.onlinedegree.iitm.ac.in': ['enterpreneurship', 'mitr'],
#  '21f1004271@student.onlinedegree.iitm.ac.in': ['developer',
#   'mitr',
#   'placement wing',
#   'research',
#   'saathi'],
#  '21f3001418@student.onlinedegree.iitm.ac.in': ['editorial', 'mitr'],
# ...

# %%
df = {}
for i in students_dict.keys():
    df[i]=[]
for i,j in students_dict.items():
    for grp in groups.keys():
#         print(i)
        if grp in j:
            df[i].append(grp)
        else:
            df[i].append("")

# %%
df
# Out:
# {'21f3003219@student.onlinedegree.iitm.ac.in': ['mitr',
#   '',
#   'developer',
#   '',
#   'placement wing',
#   'vue',
#   'regional coordinator',
#   '',
#   '',
#   '',
#   ''],
#  '21f1000080@student.onlinedegree.iitm.ac.in': ['mitr',
#   '',
#   'developer',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  '21f3002203@student.onlinedegree.iitm.ac.in': ['mitr',
#   '',
#   '',
#   '',
#   'placement wing',
#   '',
#   'regional coordinator',
#   '',
#   '',
#   '',
#   ''],
#  '21f1005470@student.onlinedegree.iitm.ac.in': ['mitr',
#   '',
#   'developer',
#   '',
#   '',
#   '',
#   'regional coordinator',
#   '',
#   '',
#   '',
#   ''],
#  '21f3001270@student.onlinedegree.iitm.ac.in': ['mitr',
#   '',
#   'developer',
#   '',
#   '',
#   'vue',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  '21f1005207@student.onlinedegree.iitm.ac.in': ['mitr',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
# ...

# %%
dataf = pd.DataFrame(df).transpose()
dataf.columns = groups.keys()

# %%
dataf
# Out:
#                                             mitr editorial  developer blog  \
# 21f3003219@student.onlinedegree.iitm.ac.in  mitr            developer
# 21f1000080@student.onlinedegree.iitm.ac.in  mitr            developer
# 21f3002203@student.onlinedegree.iitm.ac.in  mitr
# 21f1005470@student.onlinedegree.iitm.ac.in  mitr            developer
# 21f3001270@student.onlinedegree.iitm.ac.in  mitr            developer
# ...                                          ...       ...        ...  ...
# 21f1000079@student.onlinedegree.iitm.ac.in
# 21f3003246@student.onlinedegree.iitm.ac.in
# 22f1000027@student.onlinedegree.iit.ac.in
# 21f2001058@student.onlinedegree.iitm.ac.in
# 21f1001101@student.onlinedegree.iitm.ac.in
#
#                                             placement wing  vue  \
# 21f3003219@student.onlinedegree.iitm.ac.in  placement wing  vue
# 21f1000080@student.onlinedegree.iitm.ac.in
# 21f3002203@student.onlinedegree.iitm.ac.in  placement wing
# ...

# %%
dataf.to_csv('./students_list.csv')

# %% [markdown]
# # Unstructured Queries

# %%
df = pd.read_csv('./GSB SEC Meet #1 Logs.txt',sep='\n',header=None)
df
# Out:
#                                                       0
# 0     from Hariharan Balasubramanian to everyone:   ...
# 1     @IITM Host - Please make me, Kunwar, Abhinandh...
# 2     from Hariharan Balasubramanian to everyone:   ...
# 3                                           Abishek too
# 4     from Hariharan Balasubramanian to everyone:   ...
# ...                                                 ...
# 5444                                     thank you team
# 5445                   from Alf to everyone:    8:31 PM
# 5446  ananya 21f3001596@student.online degree.iitm.a...
# 5447      from Abhinandan Sethi to everyone:    8:31 PM
# 5448                https://forms.gle/hFCySMUHsDjDE73x7
#
# [5449 rows x 1 columns]

# %%
for i in students_intrested:
    if re.match('\w*[" "a-z\D]*i\s[ha]\w+',i,re.IGNORECASE):
        print(i)
# Out:
# I had managed my school events 21f3002418@student.onlinedegree.iitm.ac.in
# regional coordinator I have organised national level hackathon in my college + organised few webinars 21f2000886@student.onlinedegree.iitm.ac.in
# i have not been added to my house google space or whatsapp group 21f3001902@student.onlinedegree.iitm.ac.in
# i am i win 21f1003313@student.onlinedegree.iitm.ac.in
# isme apna kuch nhi ho skta 21f3001320@student.onlinedegree.iitm.ac.in
# i am the bad guy  ​​21f3000805@student.onlinedegree.iitm.ac.in
# i am the bad guy  ​​21f3000805@student.onlinedegree.iitm.ac.in
# asi ashwin       21f1003313@student.onlinedegree.iitm.a
# I am interested in economic + data science 21f3002330@student.onlinedegree.iitm.ac.in
